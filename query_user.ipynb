# %%
import eia as eia
import pandas as pd

# %%
eia_query = eia.weeklyReport('apiKey.txt')

# %%
eia_query.timeSeries
# Out:
#             Crude Oil  Crude Oil Excl. SPR  Crude Oil SPR  Total Gasoline  \
# reportDate
# 2022-04-01     976951               412371         564580          236787
# 2022-03-25     978272               409950         568322          238828
# 2022-03-18     984722               413399         571323          238043
# 2022-03-11     991420               415907         575513          240991
# 2022-03-04     989058               411562         577496          244606
# ...               ...                  ...            ...             ...
# 2010-07-02    1064153               337562         726591          219435
# 2010-06-25    1069198               342606         726592          218115
# 2010-06-18    1071207               344613         726594          217578
# 2010-06-11    1069190               342596         726594          218340
# 2010-06-04    1067501               340906         726595          218976
#
# ...
